# %%
! aws s3 ls dev-et-data/
# Out:
#                            PRE 01drop/
#                            PRE NDVI_filled/
#                            PRE compressed/
#                            PRE etasw_2014/
#                            PRE etasw_2015/
#                            PRE greg_outputs/
#                            PRE level-1/
#                            PRE steff_2014/
#                            PRE steff_2015/
#                            PRE t50n-90e/
#                            PRE v1DRB_outputs/
# 2020-05-05 23:59:59         62 Readme-bucket.md
# 2020-05-05 23:50:00         13 tony.txt

# %%
! aws s3 ls dev-et-data/v1DRB_outputs/model_outputs/ |grep 200[5-9][0-1][0-9].tif | grep eta

# %%
! aws s3 ls dev-et-data/v1DRB_outputs/model_outputs/ |grep 201[0-9][0-1][0-9].tif | grep eta
# Out:
# 2020-05-04 18:10:39   48459854 etasw_201310.tif
# 2020-05-04 18:20:02   48459854 etasw_201311.tif
# 2020-05-04 18:29:33   48459854 etasw_201312.tif
# 2020-05-04 18:39:05   48459854 etasw_201401.tif
# 2020-05-04 18:48:34   48459854 etasw_201402.tif
# 2020-05-04 18:57:54   48459854 etasw_201403.tif
# 2020-05-04 19:06:59   48459854 etasw_201404.tif
# 2020-05-04 19:17:05   48459854 etasw_201405.tif
# 2020-05-04 19:26:21   48459854 etasw_201406.tif
# 2020-05-04 19:35:49   48459854 etasw_201407.tif
# 2020-05-04 19:45:44   48459854 etasw_201408.tif
# 2020-05-04 19:55:06   48459854 etasw_201409.tif
# 2020-05-04 20:05:29   48459854 etasw_201410.tif
# 2020-05-04 20:15:08   48459854 etasw_201411.tif
# 2020-05-04 20:25:30   48459854 etasw_201412.tif
# 2020-05-04 20:35:03   48459854 etasw_201501.tif
# 2020-05-04 20:43:19   48459854 etasw_201502.tif
# 2020-05-04 20:53:44   48459854 etasw_201503.tif
# 2020-05-04 21:03:30   48459854 etasw_201504.tif
# 2020-05-04 21:14:42   48459854 etasw_201505.tif
# ...

# %%
! aws s3 cp s3://dev-et-data/v1DRB_outputs/model_outputs s3://dev-et-data/greg_outputs --recursive --exclude "*" --include "eta*200[5-9][0-1][0-9].tif"

# %% [markdown]
# # Go to filezilla next

# %%
# (Esc+m) - markdown

# %%
! aws s3 ls dev-et-data/etasw_2014/
# Out:
# 2020-05-07 02:39:55   48459854 etasw_2014.tif
# 2020-05-07 02:39:55   48459854 etasw_2014001.tif
# 2020-05-07 02:39:55   48459854 etasw_2014002.tif
# 2020-05-07 02:39:55   48459854 etasw_2014003.tif
# 2020-05-07 02:39:55   48459854 etasw_2014004.tif
# 2020-05-07 02:39:55   48459854 etasw_2014005.tif
# 2020-05-07 02:39:56   48459854 etasw_2014006.tif
# 2020-05-07 02:39:56   48459854 etasw_2014007.tif
# 2020-05-07 02:39:56   48459854 etasw_2014008.tif
# 2020-05-07 02:39:56   48459854 etasw_2014009.tif
# 2020-05-07 02:39:57   48459854 etasw_201401.tif
# 2020-05-07 02:39:57   48459854 etasw_2014010.tif
# 2020-05-07 02:39:58   48459854 etasw_2014011.tif
# 2020-05-07 02:39:58   48459854 etasw_2014012.tif
# 2020-05-07 02:39:58   48459854 etasw_2014013.tif
# 2020-05-07 02:39:58   48459854 etasw_2014014.tif
# 2020-05-07 02:39:58   48459854 etasw_2014015.tif
# 2020-05-07 02:39:59   48459854 etasw_2014016.tif
# 2020-05-07 02:39:59   48459854 etasw_2014017.tif
# ...

# %%
! aws s3 rm s3://dev-et-data/00drop/ --recursive
# Out:
# delete: s3://dev-et-data/00drop/dd_201311.tif
# delete: s3://dev-et-data/00drop/dd_2013.tif
# delete: s3://dev-et-data/00drop/dd_2013280.tif
# delete: s3://dev-et-data/00drop/dd_2013278.tif
# delete: s3://dev-et-data/00drop/dd_2013277.tif
# delete: s3://dev-et-data/00drop/dd_2013281.tif
# delete: s3://dev-et-data/00drop/dd_2013274.tif
# delete: s3://dev-et-data/00drop/dd_201310.tif
# delete: s3://dev-et-data/00drop/dd_2013289.tif
# delete: s3://dev-et-data/00drop/dd_201312.tif
# delete: s3://dev-et-data/00drop/dd_2013283.tif
# delete: s3://dev-et-data/00drop/dd_2013275.tif
# delete: s3://dev-et-data/00drop/dd_2013282.tif
# delete: s3://dev-et-data/00drop/dd_2013288.tif
# delete: s3://dev-et-data/00drop/dd_2013284.tif
# delete: s3://dev-et-data/00drop/dd_2013286.tif
# delete: s3://dev-et-data/00drop/dd_2013290.tif
# delete: s3://dev-et-data/00drop/dd_2013291.tif
# delete: s3://dev-et-data/00drop/dd_2013285.tif
# delete: s3://dev-et-data/00drop/dd_2013294.tif
# ...

# %%
! aws s3 ls s3://dev-et-data/01drop/ --recursive | wc -l
# Out:
# 1126
